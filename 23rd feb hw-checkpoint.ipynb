# %% [markdown]
# # type casting

# %% [markdown]
# # other datatypes to bool

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool()
# Out:
# False

# %%
bool(@)
# Out:
#   Cell In[4], line 1
#     bool(@)
#          ^
# SyntaxError: invalid syntax

# %%
bool(1.2)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(00.1)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool(2+)
# Out:
#   Cell In[11], line 1
#     bool(2+)
#            ^
# SyntaxError: invalid syntax

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool('zero') # other datatype to string is possible
# Out:
# True

# %% [markdown]
# # other datatypes to string

# %%
str(1)
# Out:
# '1'

# %%
str(10)
# Out:
# '10'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(True)
# Out:
# 'True'

# %%
int(True)
# Out:
# 1

# %%
bool(True)
# Out:
# True

# %%
str(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 str(true)
#
# NameError: name 'true' is not defined

# %%
str(False)
# Out:
# 'False'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %% [markdown]
# # operators

# %% [markdown]
# # arithmetic operator

# %%
x1, y1 = 10,5

# %%
#x1 ^ y1

# %%
x1 + y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
x1**y1
# Out:
# 100000

# %%
x2 = 3
y2 = 3

x2**y2
# Out:
# 27

# %% [markdown]
#  # asssignment operator

# %%
x = 2

# %%
x = x+2

# %%
x
# Out:
# 4

# %%
x +=2
x
# Out:
# 6

# %%
x +=2
x
# Out:
# 8

# %%
x *=2

# %%
x
# Out:
# 16

# %%
x -=2

# %%
x
# Out:
# 14

# %%
x//=2

# %%
x
# Out:
# 7

# %%
x/2
# Out:
# 3.5

# %%
x4 = 10
x4 %=2
x4
# Out:
# 0

# %% [markdown]
# # relational operators

# %%
a = 5
b = 6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a=5
b=5

# %%
a==b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# False

# %%
a=5
b=7

# %%
print(a)
print(b)
# Out:
# 5
# 7

# %%
a!=b
# Out:
# True

# %% [markdown]
# # unary operator

# %%
n=7
n
# Out:
# 7

# %%
m =-(n)

# %%
m
# Out:
# -7

# %%
n
# Out:
# 7

# %%
-n
# Out:
# -7

# %% [markdown]
# # logical operator

# %%
a=5
b=4

# %%
a<8 and b<5
# Out:
# True

# %%
a<8 or b<2
# Out:
# True

# %%
x=False
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
x= not x
x
# Out:
# True

# %%
x
# Out:
# True

# %% [markdown]
# # home work

# %%
1+1
# Out:
# 2

# %%
2-1
# Out:
# 1

# %%
3*4
# Out:
# 12

# %%
8/4
# Out:
# 2.0

# %%
8/5
# Out:
# 1.6

# %%
8//4
# Out:
# 2

# %%
8+9-7
# Out:
# 10

# %%
8+8-
# Out:
#   Cell In[121], line 1
#     8+8-
#         ^
# SyntaxError: invalid syntax

# %%
5+5*5
# Out:
# 30

# %%
(5+5)*5 #bodmas bracket order
# Out:
# 50

# %%
2*2*2*2*2
# Out:
# 32

# %%
2*5
# Out:
# 10

# %%
2**5
# Out:
# 32

# %%
15/3
# Out:
# 5.0

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
11//3
# Out:
# 3

# %%
12//3
# Out:
# 4

# %%
15%2
# Out:
# 1

# %%
10%2
# Out:
# 0

# %%
15 %% 2
# Out:
#   Cell In[137], line 1
#     15 %% 2
#         ^
# SyntaxError: invalid syntax

# %%
3+ 'nit'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 3+ 'nit'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a,b,c,d,e = 15, 7.8, 'nit', 8+9j, True
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 15
# 7.8
# nit
# (8+9j)
# True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'complex'>
# <class 'bool'>

# %%
type(c)
# Out:
# str

# %%
'Naresh IT'
# Out:
# 'Naresh IT'

# %%
print('Max it')
# Out:
# Max it

# %%
'Max it'
# Out:
# 'Max it'

# %%
'Max it technology'
# Out:
# 'Max it technology'

# %%
s1='Max it technology'
s1
# Out:
# 'Max it technology'

# %%
a=2
b=3
a+b
# Out:
# 5

# %%
c=a+b
c
# Out:
# 5

# %%
a=3
b='hi'
type(b)
# Out:
# str

# %%
print('max it's "technology"') # \ has some special meaning to ignore the error
# Out:
#   Cell In[154], line 1
#     print('max it's "technology"') # \ has some special meaning to ignore the error
#                                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('max it\'s "technology"') # \ has some special meaning to ignore the error
# Out:
# max it's "technology"

# %%
print('max it' , 'Technology')
# Out:
# max it Technology

# %%
print("max it", "Technology")
# Out:
# max it Technology

# %%
# print the nit 2 times
'nit'  +   "nit"
# Out:
# 'nitnit'

# %%
'nit' 'nit'
# Out:
# 'nitnit'

# %%
# 5 time print
5* 'nit'
# Out:
# 'nitnitnitnitnit'

# %%
5* ' nit' # space between words
# Out:
# ' nit nit nit nit nit'

# %%
print('c:\nit') # \n -- new line
# Out:
# c:
# it

# %%
print(r'c:\nit') # raw string
# Out:
# c:\nit

# %% [markdown]
# # variable, identifier, object

# %%
2
# Out:
# 2

# %%
x=2

# %%
x+3
# Out:
# 5

# %%
y=3

# %%
x+y
# Out:
# 5

# %%
x=9

# %%
x+y
# Out:
# 12

# %%
x+10
# Out:
# 19

# %%
_+y
# Out:
# 22

# %%
_+y
# Out:
# 25

# %%
_+y
# Out:
# 28

# %%
_+y
# Out:
# 31

# %%
y
# Out:
# 3

# %%
_+y
# Out:
# 6

# %%
_+y
# Out:
# 9

# %%
_+y
# Out:
# 12

# %%
# string variable
name='mit'

# %%
name
# Out:
# 'mit'

# %%
name+'technology'
# Out:
# 'mittechnology'

# %%
name+' technology'
# Out:
# 'mit technology'

# %%
name 'technology'
# Out:
#   Cell In[197], line 1
#     name 'technology'
#          ^
# SyntaxError: invalid syntax

# %%
name
# Out:
# 'mit'

# %%
len('name')
# Out:
# 4

# %%
name[0]
# Out:
# 'm'

# %%
name[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 name[5]
#
# IndexError: string index out of range

# %%
name[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[202], line 1
# ----> 1 name[7]
#
# IndexError: string index out of range

# %%
name[-1]
# Out:
# 't'

# %%
name[-2]
# Out:
# 'i'

# %%
name[-6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[205], line 1
# ----> 1 name[-6]
#
# IndexError: string index out of range

# %% [markdown]
# # slicing

# %%
name
# Out:
# 'mit'

# %%
name[0:1]
# Out:
# 'm'

# %%
name[0:2]
# Out:
# 'mi'

# %%
name[1:4]
# Out:
# 'it'

# %%
name[1:]
# Out:
# 'it'

# %%
name[:4]
# Out:
# 'mit'

# %%
name[3:9]
# Out:
# ''

# %%
name
# Out:
# 'mit'

# %%
name1 = 'fine' # change the string fine to dine
name1
# Out:
# 'fine'

# %%
name1[0:1]
# Out:
# 'f'

# %%
name1[0:1] = 'd' # i want to change 1st chracter of naresh(n)- t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 name1[0:1] = 'd' # i want to change 1st chracter of naresh(n)- t
#
# TypeError: 'str' object does not support item assignment

# %%
name1[0]= 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[239], line 1
# ----> 1 name1[0]= 'd'
#
# TypeError: 'str' object does not support item assignment

# %%
name1
# Out:
# 'fine'

# %%
name1[1:]
# Out:
# 'ine'

# %%
'd' +name1[1:] # i want to change fine to dine
# Out:
# 'dine'

# %%
num1.insert(2,'nit') # insert the value as per index value i.e 2nd index we are ssigning nit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[246], line 1
# ----> 1 num1.insert(2,'nit') # insert the value as per index value i.e 2nd index we are ssigning nit
#
# NameError: name 'num1' is not defined

# %% [markdown]
# # introduce to ID()

# %%
# variable address
num = 5
id(num)
# Out:
# 140716605875240

# %%
name= 'nit'
id(name) # adress will be different for both
# Out:
# 1556785127344

# %%
a = 10
id(a)
# Out:
# 140716605875400

# %%
b = a # thats why python is more memory efficient

# %%
id(b)
# Out:
# 140716605875400

# %%
id(10)
# Out:
# 140716605875400

# %%
k = 10
id(k)
# Out:
# 140716605875400

# %%
a = 20 # as we change the value of a then address will change
id(a)
# Out:
# 140716605875720

# %%
id(b)
# Out:
# 140716605875400

# %%
id(10)
# Out:
# 140716605875400

# %%
k = 10
id(k)
# Out:
# 140716605875400

# %%
a = 20
id(a)
# Out:
# 140716605875720

# %% [raw]
# whatever the variable we assigned the nemory and we not assigned anywhere then we use as garbage collection. || variable- we can change the values|| constant- we cannot change the value-can we make variable as a constant (note- in python you cannot make variable as constant)

# %%
PI = 3.14 #in math this is alway constant but python we can change

# %%
PI
# Out:
# 3.14

# %%
PI = 3.15
PI
# Out:
# 3.15

# %%
type(PI)
# Out:
# float
