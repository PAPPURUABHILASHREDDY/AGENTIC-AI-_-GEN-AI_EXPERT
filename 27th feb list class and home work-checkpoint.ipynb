# %% [markdown]
# # inbuilt datastructures

# %% [markdown]
# # list

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %% [raw]
# l.    # use "l.tab" to see inbuilt function

# %% [markdown]
# # append()

# %% [raw]
# use l.append and then shift tab to see what append function can do

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20,30) # it shows error because list append takes exactly one argument , but here we gave two , so it shows type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 l.append(20,30) # it shows error because list append takes exactly one argument , but here we gave two , so it shows type error
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1 = []
l1
# Out:
# []

# %% [markdown]
# # copy()

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1==l
# Out:
# True

# %%
print(id(l))
print(id(l1))
# Out:
# 2944912432064
# 2944911797760

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 20, 30, 40, 50, 10]

# %%
l2 = []
l2
# Out:
# []

# %%
l2.append(2)
l2.append(2.3)
l2.append(True)
l2.append(1+2j)
l2.append('nit')
l2.append([1,2,3])

# %%
l2
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 20, 30, 40, 50, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %% [markdown]
# # clear()

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l.clear()

# %%
l
# Out:
# []

# %% [markdown]
# # del

# %%
del l

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %% [markdown]
# # count()

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1.count(20) # do shift tab to see what it does
# Out:
# 1

# %%
l1.count(10)
# Out:
# 2

# %% [markdown]
# # extend()

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.extend(l2)  # extend one list to other which is concatenation

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %% [raw]
# # copy vs extend
#   copy only one list to another list
#   copy override the existing data
#
#   extend merge 2 to more list
#   and ectend can concat

# %% [markdown]
# # index()

# %%
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1 # see the difference between print(l1) and l1
# Out:
# [10, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.index(20)
# Out:
# 1

# %%
l1.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 l1.index()
#
# TypeError: index expected at least 1 argument, got 0

# %%
l1.index(2.3)
# Out:
# 7

# %%
l1.index(200) #### value error = 200 is not in the list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 l1.index(200) #### value error = 200 is not in the list
#
# ValueError: 200 is not in list

# %%
print(l2)
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l2.index([1,2,3])
# Out:
# 5

# %% [markdown]
# # now you want to display all the values of l2

# %%
l2
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %% [raw]
# for this we use loops

# %%
for i in l2:         # by applying loops we can release these elements in l2 one by one
    print (i)
# Out:
# 2
# 2.3
# True
# (1+2j)
# nit
# [1, 2, 3]

# %%
for i in l1:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50
# 10
# 2
# 2.3
# True
# (1+2j)
# nit
# [1, 2, 3]

# %% [markdown]
# # insert()

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %% [raw]
# question : insert 15 between 10 and 20

# %%
l1.insert(1,15)  ### insert object before index (not after index)

# %% [raw]
# (q) add 23 between 20 and 30

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %% [raw]
# (q) add 23 between 20 and 30

# %%
l1.insert(3,23)

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %% [markdown]
# # pop()

# %% [raw]
# # IF () IS EMPTY THEN BY DEFAULT IT WILL TAKE LAST ONE
# IT WILL REMOVE THE LAST ONE AND DISPLAY IT

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.pop()
# Out:
# [1, 2, 3]

# %%
l1
# Out:
# [10, 15, 20, 23, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit']

# %%
l1.pop(3)
# Out:
# 23

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit']

# %%
l1.pop(20)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 l1.pop(20)
#
# IndexError: pop index out of range

# %% [markdown]
# # remove()

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, (1+2j), 'nit']

# %%
l1.remove(200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 l1.remove(200)
#
# ValueError: list.remove(x): x not in list

# %%
l1.remove((1+2j))

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, 'nit']

# %% [raw]
# # pop() removes based on index
#   remove() removes based on element/value

# %% [markdown]
# # home work

# %% [markdown]
# # list

# %%
list1 = []

# %%
list1
# Out:
# []

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list2 = [10,30,60] # list of integers numbers

# %%
list3 = [10.77,30.66,60.89] # list of float numbers

# %%
list4 = ['one','two',"three"] # list of strings

# %%
list5 = ['Asif',25,[50,100],[150,90]] # nested list

# %%
list6 = [100,'Asif',17.765] # list of mixed data types

# %%
list7 = ['Asif', 25 ,[50,100],[150,90],{'john','David'}]

# %%
len(list6) # length of list
# Out:
# 3

# %% [markdown]
# # list indexing

# %%
list2[0]
# Out:
# 10

# %%
list4[0]
# Out:
# 'one'

# %%
list4[0][0] # nested indexing- access the 1st character of the 1st list
# Out:
# 'o'

# %%
list4[-1]
# Out:
# 'three'

# %%
list5[-1]
# Out:
# [150, 90]

# %% [markdown]
# # list slicing

# %%
mylist = ['one', 'two','three','four','five','six','seven','eight']

# %%
mylist[0:3]
# Out:
# ['one', 'two', 'three']

# %%
mylist[2:5]
# Out:
# ['three', 'four', 'five']

# %%
mylist[:3]
# Out:
# ['one', 'two', 'three']

# %%
mylist[:2]
# Out:
# ['one', 'two']

# %%
mylist[-3:]
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-2:]
# Out:
# ['seven', 'eight']

# %%
mylist[-1]
# Out:
# 'eight'

# %%
mylist[:]
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # add, remove & chnage items

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.append('nine')

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.insert(9,'ten') ##### ADD THE ITEM AT INDEX LOCATION 9
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.insert(1,'ONE')
mylist
# Out:
# ['one',
#  'ONE',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten']

# %%
mylist.remove('ONE')
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.pop() # remove last item of the list by default sine no value is given in ()
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.pop(8)
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
del mylist[7] # remove item at index location 7
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
# change the value of the string
mylist[0]=1
mylist[1]=2
mylist[2]=3
mylist
# Out:
# [1, 2, 3, 'four', 'five', 'six', 'seven']

# %%
mylist.clear() # empty list/ delete all items in the list
mylist
# Out:
# []

# %%
del mylist # delete the whole list
mylist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[180], line 2
#       1 del mylist # delete the whole list
# ----> 2 mylist
#
# NameError: name 'mylist' is not defined

# %% [markdown]
# # copy list

# %%
mylist = ['one', 'two','three','four','five','six','seven','eight','nine']

# %%
mylist1 = mylist # create a new referance "mylist1"

# %%
id(mylist), id(mylist1) # the adress of both will be same
# Out:
# (2944913102272, 2944913102272)

# %%
mylist2 = mylist.copy() # create a copy of the list

# %%
id(mylist2) # the address of mylist2 will be different
# Out:
# 2944913190976

# %%
mylist3 = mylist2

# %%
id(mylist3), id(mylist2)
# Out:
# (2944913190976, 2944913190976)

# %%
mylist[0] = 1

# %%
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 # mylist1 will also be impacted as it is pointing to the same list
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist2 # this won't impacted
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# # join lists

# %%
list1 = ['one','two','three','four']
list2 = ['five','six','seven','eight']

# %%
list3 = list1+list2 # join 2 lists by '+' operator
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2) # append list 2 with list 1

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # list membership

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
'one' in list1 # check if 'one' exist in the list
# Out:
# True

# %%
'ten' in list1 # check if 'ten' exist in the list
# Out:
# False

# %%
if 'three' in list1:   # check if 'three' exist in the list
    print('three is present in the list')
else:
    print('three is not present in the list')
# Out:
# three is present in the list

# %%
if 'eleven' in list1:
    print('eleven is present in the list')
else:
    print('eleven is not present in the lsit')
# Out:
# eleven is not present in the lsit

# %% [markdown]
# # reverse & sort list

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse() # reverse the list
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1 = list1[::-1]  # reverse the list
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1[:]
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1[::] ############
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1[:::] ############
# Out:
#   Cell In[212], line 1
#     list1[:::]
#             ^
# SyntaxError: invalid syntax

# %%
list1[::1] ###########
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1[::2] ########
# Out:
# ['one', 'three', 'five', 'seven']

# %%
list1[::3] ############
# Out:
# ['one', 'four', 'seven']

# %%
list1[3::]
# Out:
# ['four', 'five', 'six', 'seven', 'eight']

# %%
list1[1::] ##################
# Out:
# ['two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1[2::]
# Out:
# ['three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1[::-2]
# Out:
# ['eight', 'six', 'four', 'two']

# %%
list1[::-1]
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1[::-3]
# Out:
# ['eight', 'five', 'two']

# %%
list1[::-4]
# Out:
# ['eight', 'four']

# %%
list1[::-5]
# Out:
# ['eight', 'three']

# %%
list[::-6] ###################??????????????????????????
# Out:
# list[slice(None, None, -6)]

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort()   # sort list in ascending order
mylist3
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort(reverse=True)   # sort list in descending order
mylist3
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %%
mylist4 = [88,65,33,21,11,98]
sorted(mylist4)    # returns a new sorted list and doesn't change original list
# Out:
# [11, 21, 33, 65, 88, 98]

# %%
mylist4
# Out:
# [88, 65, 33, 21, 11, 98]

# %% [markdown]
# # loop through a list

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
for i in list1:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(list1):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# # count

# %%
list10 = ['one','two','three','four','one','one','two','three']

# %%
list10.count('one') # no of times 'one' occured in the list
# Out:
# 3

# %%
list10.count('two')
# Out:
# 2

# %%
list10.count('four')
# Out:
# 1

# %% [markdown]
# # all/any

# %% [raw]
# # returns
# in all()
# True - if all elements in a list are true
# False - if any element in a list is false
#
# in any()
# returns
# True - if any elements in the list is true
# False - if not, any() returns false

# %%
L1 = [1,2,3,4,0]

# %%
all(L1) # will return false as one value is false (value 0)
# Out:
# False

# %%
any(L1) # will return true as we have items in the list with true value
# Out:
# True

# %%
L2 = [1,2,3,4,True,False]

# %%
all(L2) # returns false as one value is false
# Out:
# False

# %%
any(L2) # returns true as we have items in the list with true value
# Out:
# True

# %%
L3 = [1,2,3,True]

# %%
all(L3) # will return True as all items in the list are True
# Out:
# True
