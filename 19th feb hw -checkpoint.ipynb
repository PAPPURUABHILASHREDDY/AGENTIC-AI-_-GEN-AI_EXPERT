# %% [markdown]
# # variable

# %%
a = 5
b =10
result = a+b

# %%
print(result)
# Out:
# 15

# %%
score=50

# %%
print(score)
# Out:
# 50

# %%
score=100

# %%
print(score)
# Out:
# 100

# %%
first_name= "abhilash"
last_name= "reddy"

# %%
full_name = first_name+" "+last_name

# %%
print(full_name)
# Out:
# abhilash reddy

# %%
length=10
width=5

# %%
length*width
# Out:
# 50

# %% [markdown]
# # type casting

# %%
int(230.34)  # float to int
# Out:
# 230

# %%
int(230.34, 110.23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 int(230.34, 110.23)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)  #bool to int
# Out:
# 1

# %%
int(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 int(true)
#
# NameError: name 'true' is not defined

# %%
int(False)
# Out:
# 0

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int("10")
# Out:
# 10

# %%
int("ten")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 int("ten")
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # other datatypes to float type conversion

# %%
float(23)
# Out:
# 23.0

# %%
float(True)
# Out:
# 1.0

# %%
float(1+2J)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 float(1+2J)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float("20")
# Out:
# 20.0

# %%
float("ten")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 float("ten")
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# # other datatype to complex

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(10.3)
# Out:
# (10.3+0j)

# %%
complex(10.3,23)
# Out:
# (10.3+23j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(False,False)
# Out:
# 0j

# %%
p,q=20,20

# %%
print(p)
print(q)
# Out:
# 20
# 20

# %%
print(id(p))
print(id(q))
# Out:
# 140717336667656
# 140717336667656

# %%
complex("10")
# Out:
# (10+0j)

# %%
complex("20","10")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 complex("20","10")
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# # python tutorial

# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %% [markdown]
# # keywords

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # comments in python

# %%
# single line comment
val1 = 10

# %%
# multiple
# line 
# comment
val1 = 10

# %%
'''
Multiple
line
comment
'''
val1 = 10

# %%
"""
multiple
line
comment
"""
val1 = 10

# %% [markdown]
# # statements

# %%
p = 20
q = 20
r = q
p, type(p), hex(id(p)) # what is hex
# Out:
# (20, int, '0x7ffb4edda608')

# %%
q, type(q), hex(id(q))
# Out:
# (20, int, '0x7ffb4edda608')

# %%
r, type(r), hex(id(r))
# Out:
# (20, int, '0x7ffb4edda608')

# %% [markdown]
# # variable assignment

# %% [markdown]
# intvar = 10
# floatvar = 2.57
# strvar = "Python Language"
#
# print(intvar)
# print(floatvar)
# print(strvar)

# %% [markdown]
# # multiple assignment

# %%
intvar,floatvar,strvar=10,2.57,"Python Language"
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %%
p1=p2=p3=p4=44
print(p1,p2,p3,p4)
# Out:
# 44 44 44 44

# %% [markdown]
# # data types

# %% [markdown]
# # numeric

# %%
val1 = 10
print(val1)
print(type(val1))
print(sys.getsizeof(val1))    # wtf are these
print(val1, " is integer?", isinstance(val1, int))
# Out:
# 10
# <class 'int'>
# 28
# 10  is integer? True

# %%
val2 = 97.78
print(val2)
print(type(val2))
print(sys.getsizeof(val2))    # wtf are these
print(val2, " is float?", isinstance(val2, float))
# Out:
# 97.78
# <class 'float'>
# 24
# 97.78  is float? True

# %%
val3 = 25+10j
print(val3)
print(type(val3))
print(sys.getsizeof(val3))    # wtf are these
print(val3, " is complex?", isinstance(val3, complex))
# Out:
# (25+10j)
# <class 'complex'>
# 32
# (25+10j)  is complex? True

# %%
sys.getsizeof(int())
# Out:
# 28

# %%
sys.getsizeof(float())
# Out:
# 24

# %%
sys.getsizeof(complex())
# Out:
# 32

# %% [markdown]
# # boolean

# %%
bool1 = True
bool2 = False
print(type(bool1))
print(type(bool2))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
isinstance(bool1,bool)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(False)
# Out:
# False

# %% [markdown]
# # string

# %%
myst = """Hello
          World"""
print(myst)
# Out:
# Hello
#           World

# %%
myst = '''Hello
          World'''
print(myst)
# Out:
# Hello
#           World

# %%
myst = ('Happy '
       'monday '
       'everyone') # new # use space after happy and monday to get space betweeen words

print(myst)
# Out:
# Happy monday everyone

# %%
myst2 = 'WOHOO'
myst2 = myst2*5
myst2
# Out:
# 'WOHOOWOHOOWOHOOWOHOOWOHOO'

# %%
len(myst2)
# Out:
# 25

# %% [markdown]
# # string indexing

# %%
str1 = 'HELLO PYTHON'

# %%
str1
# Out:
# 'HELLO PYTHON'

# %%
str1[0]
# Out:
# 'H'

# %%
str1[len(str1)-1]
# Out:
# 'N'

# %%
str1[-1]
# Out:
# 'N'

# %%
str1[6]
# Out:
# 'P'

# %%
str1[5]
# Out:
# ' '

# %% [markdown]
# # string slicing

# %%
str1[0:5]
# Out:
# 'HELLO'

# %%
str1[6:12]
# Out:
# 'PYTHON'

# %%
str1[-4:]
# Out:
# 'THON'

# %%
str1[-6:]
# Out:
# 'PYTHON'

# %%
str1[:4]
# Out:
# 'HELL'

# %%
str1[:6]
# Out:
# 'HELLO '

# %% [markdown]
# # update & delete string

# %%
str1
# Out:
# 'HELLO PYTHON'

# %%
str1[0:5] = 'HOLLA'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 str1[0:5] = 'HOLLA'
#
# TypeError: 'str' object does not support item assignment

# %%
del str1
print(srt1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 del str1
#       2 print(srt1)
#
# NameError: name 'str1' is not defined

# %% [markdown]
# # string concatenation

# %%
s1= "hello"
s2= "asif"
s3=s1+s2
print(s3)
# Out:
# helloasif

# %% [markdown]
# # print results with string

# %%
num1 = 20
num2 = 30
add=num1+num2
print('The addition of',num1,'and',num2,'is =',add)
# Out:
# The addition of 20 and 30 is = 50

# %%
name="python"
age=20
city="hyd"

# %%
print("My name is",name,"and i am",age,"years old from",city)
# Out:
# My name is python and i am 20 years old from hyd

# %%
num1=20
num2=30
add=num1+num2
print("the addition of{}and{}is={}".format(num1,num2,add))
# Out:
# the addition of20and30is=50

# %%
name="python"
age=20
city="hyd"

# %%
print("hello my name is {},and i am {}years old from {}".format(name,age,city))
# Out:
# hello my name is python,and i am 20years old from hyd

# %%
num1=100
num2=25
num3=333
avg=(num1+num2+num3)/3#or we can use avg= round(num1+num2+num3)
avg1=round((num1+num2+num3)/3,2)

# %%
print("The avrage of {},{}, and {} is= {} or {}".format(num1,num2,num3,avg,avg1))
# Out:
# The avrage of 100,25, and 333 is= 152.66666666666666 or 152.67

# %%
round(avg,2)
# Out:
# 152.67

# %% [markdown]
# # f string  method or short format method

# %%
num1=20
num2=30
add=num1+num2
print(f"the addition of {num1} and {num2} is= {add}")
# Out:
# the addition of 20 and 30 is= 50

# %%
name="python"
age=20
city="hyd"
print(f"hello my name is {name}, and i am {age} year old, from {city}")
# Out:
# hello my name is python, and i am 20 year old, from hyd

# %%
num1=100
num2=25
num3=333
avg=round((num1+num2+num3)/3,2)

# %%
print(f"the average of {num1}, {num2} and{num3} is = {avg} ")
# Out:
# the average of 100, 25 and333 is = 152.67

# %%
# Letecombine all
num1=10
num2=20
add=num1+num2
print("the addition of",num1,"and",num2,"is",add)
# Out:
# the addition of 10 and 20 is 30

# %%
print("the addition of{} and {} is {}" . format(num1,num2,add))
# Out:
# the addition of10 and 20 is 30

# %%
print(f"the addition of{num1} and{num2} is= {add}")
# Out:
# the addition of10 and20 is= 30

# %% [markdown]
# # end statement

# %%
print('hello')
print('good moorning')
# Out:
# hello
# good moorning

# %%
print('hello', end=' ')
print('world good day')
# Out:
# hello world good day

# %% [markdown]
# # seprator

# %%
print('hello','hai','how are you',sep='- - ->')
# Out:
# hello- - ->hai- - ->how are you

# %%
print('hello','hai','how are you',sep='&')
# Out:
# hello&hai&how are you

# %%
print('hello','hai','how are you',sep='@')
# Out:
# hello@hai@how are you

# %%
print('hello','hai','how are you',sep=' ')
# Out:
# hello hai how are you

# %%
print(3, '_')#_is far from 3 so here we will use sep method
# Out:
# 3 _

# %%
print(3,'_',sep='')# see now space settled(also use to remove space B/W words)
# Out:
# 3_

# %%
print(1,2,end=' ')
print(3,'_',sep='')# we print1 2 3 _
# Out:
# 1 2 3_

# %% [markdown]
# # complex data type

# %% [markdown]
# # operations with complex numbers

# %%
z = 3+4j
print(z.real)
print(z.imag)
# Out:
# 3.0
# 4.0

# %%
a=3+4j
b=1+2j

# %%
print(a+b)
# Out:
# (4+6j)

# %%
print(a-b)
# Out:
# (2+2j)

# %%
print(a*b)
# Out:
# (-5+10j)

# %%
print(a/b)
# Out:
# (2.2-0.4j)

# %% [markdown]
# # using built in fuction

# %%
z = 3+4j
print(abs(z))
print(z.conjugate()) # wtf is this
# Out:
# 5.0
# (3-4j)

# %% [markdown]
# # complex numbers in cmath module

# %%
import cmath

z= 1+1j
print(cmath.phase(z))
print(cmath.polar(z))
print(cmath.sqrt(z))
# Out:
# 0.7853981633974483
# (1.4142135623730951, 0.7853981633974483)
# (1.09868411346781+0.45508986056222733j)
