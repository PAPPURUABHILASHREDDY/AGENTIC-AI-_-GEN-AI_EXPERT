# %% [markdown]
# # list [] indexing and slicing

# %%
l1 = [10,15,20,30,40,50,10,2,2.3,True,'nit']

# %%
l1[2:]
# Out:
# [20, 30, 40, 50, 10, 2, 2.3, True, 'nit']

# %%
l1[:2]
# Out:
# [10, 15]

# %%
l1[::2] # 2 here is a step
# Out:
# [10, 20, 40, 10, 2.3, 'nit']

# %%
l1[::3]
# Out:
# [10, 30, 10, True]

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, 'nit']

# %%
l1[2:10:4] # 'nit' won't come here because 10th index become 10-1 = 9
# Out:
# [20, 10]

# %%
l1[2:11:4] # now we can see 'nit'
# Out:
# [20, 10, 'nit']

# %%
l1[::-1] # reverse order
# Out:
# ['nit', True, 2.3, 2, 10, 50, 40, 30, 20, 15, 10]

# %%
l1[::-2]
# Out:
# ['nit', 2.3, 10, 40, 20, 10]

# %%
l1[::-5]
# Out:
# ['nit', 50, 10]

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, 'nit']

# %%
l1[-10:0:3] # not possible
# Out:
# []

# %%
l1[-10:0:-2] ###########################
# Out:
# [15]

# %%
l1[::-3]
# Out:
# ['nit', 2, 40, 15]

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, 'nit']

# %%
l2 = ['a','b','c']

# %%
l2
# Out:
# ['a', 'b', 'c']

# %%
l2[-4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 l2[-4]
#
# IndexError: list index out of range

# %%
l2[-4:]
# Out:
# ['a', 'b', 'c']

# %%
l2[-5:]
# Out:
# ['a', 'b', 'c']

# %%
l2
# Out:
# ['a', 'b', 'c']

# %%
l2[0]
# Out:
# 'a'

# %%
l2[0] = 'prakash' ## concept is mutable
                   #List Is mutabble

# %%
l2
# Out:
# ['prakash', 'b', 'c']

# %%
l2[0] = 'nit'

# %%
l2
# Out:
# ['nit', 'b', 'c']

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, 'nit']

# %%
l1[4] = 400 # list is mutable

# %%
l1
# Out:
# [10, 15, 20, 30, 400, 50, 10, 2, 2.3, True, 'nit']

# %%
l1
# Out:
# [10, 15, 20, 30, 400, 50, 10, 2, 2.3, True, 'nit']

# %%
l1.index('nit')
# Out:
# 10

# %%
l1[10]
# Out:
# 'nit'

# %%
print(l1[10][0]) ## nested indexing : "index with in a index"
# Out:
# n

# %%
print(l1[10][0])
print(l1[10][1])
print(l1[10][2])
# Out:
# n
# i
# t

# %%
l1
# Out:
# [10, 15, 20, 30, 400, 50, 10, 2, 2.3, True, 'nit']

# %% [markdown]
# # reverse()

# %%
l1.reverse()

# %%
l1
# Out:
# ['nit', True, 2.3, 2, 10, 50, 400, 30, 20, 15, 10]

# %% [raw]
# question : see the notes

# %%
l1
# Out:
# ['nit', True, 2.3, 2, 10, 50, 400, 30, 20, 15, 10]

# %%
l2
# Out:
# ['nit', 'b', 'c']

# %% [markdown]
# # sort()

# %%
l2
# Out:
# ['nit', 'b', 'c']

# %%
l2.sort()

# %%
l2 ### ascending order
# Out:
# ['b', 'c', 'nit']

# %%
l2.sort(reverse=True)

# %%
l2
# Out:
# ['nit', 'c', 'b']

# %%
l2.sort(reverse=False)

# %%
l2
# Out:
# ['b', 'c', 'nit']

# %%
l1
# Out:
# ['nit', True, 2.3, 2, 10, 50, 400, 30, 20, 15, 10]

# %%
l1.sort() ## type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 l1.sort() ## type error
#
# TypeError: '<' not supported between instances of 'bool' and 'str'

# %% [raw]
# sort() functions always work with similar datatypes, if we pass different datatypes it will throw an error

# %% [markdown]
# # loops

# %%
for i in l2:
    print(i)
# Out:
# b
# c
# nit

# %%
for i in enumerate(l2):  # it(enumerate) will give paired items
    print(i)
# Out:
# (0, 'b')
# (1, 'c')
# (2, 'nit')

# %% [markdown]
# # tuple()

# %%
# tuple is encotted with()
# list is []
# list is mutable
# tuple is immutable
# in tuple user can define multiple data types
# in tuple duplication is allowed

# %%
t = ()
t
# Out:
# ()

# %% [raw]
# t.tab we see only 2 functions

# %%
t1 = (10,20,30,40,50,50)

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t2 = (10, 'prakash',1+2j,True,2.3)

# %%
print(t1)
print(t2)
# Out:
# (10, 20, 30, 40, 50, 50)
# (10, 'prakash', (1+2j), True, 2.3)

# %%
print(type(t1))
print(type(t2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
t1.count(50)
# Out:
# 2

# %%
t1.index(10)
# Out:
# 0

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1[:4]
# Out:
# (10, 20, 30, 40)

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1[4]
# Out:
# 50

# %%
t1[5]
# Out:
# 50

# %%
t1[5] = 60
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t1[5] = 60
#
# TypeError: 'tuple' object does not support item assignment

# %%
icici = (123, 'cizps43443')
icici
# Out:
# (123, 'cizps43443')

# %%
icici[0] = 456
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 icici[0] = 456
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1*3
# Out:
# (10, 20, 30, 40, 50, 50, 10, 20, 30, 40, 50, 50, 10, 20, 30, 40, 50, 50)

# %% [markdown]
# # tuple done

# %% [markdown]
# # set{}

# %%
s = {}
s
# Out:
# {}

# %%
type(s) # if you don't type anything in set {} then by default it will turn into dictionary
# Out:
# dict

# %% [raw]
# # to get answer as a set

# %%
s = set()
s
# Out:
# set()

# %%
type(s)
# Out:
# set

# %% [markdown]
# # home work

# %% [markdown]
# # tuple creation

# %%
tup1 = ()  # empty tuple

# %%
tup2 = (10,30,60)  # tuple of integers numbers

# %%
tup3 = (10,77,30.66,60.89) # tuple of float numbers

# %%
tup4 = ('one','two',"three") # tuple of strings

# %%
tup5 = ('asif',25,(50,100),(150,90)) # nested tuples

# %%
tup6 = (100,'asif',17.765) # tuple of mixed data types

# %%
tup7 = ('asif',25,[50,100],[150,90],{'john','David'},(99,22,33))

# %%
len(tup7) # length of list
# Out:
# 6

# %% [markdown]
# # tuple indexing

# %%
tup2[0]
# Out:
# 10

# %%
tup4[0]
# Out:
# 'one'

# %%
tup4[0][0]
# Out:
# 'o'

# %%
tup4[-1]
# Out:
# 'three'

# %%
tup5[-1]
# Out:
# (150, 90)

# %% [markdown]
# # tuple slicing

# %%
mytuple = ('one','two','three','four','five','six','seven','eight')

# %%
mytuple[0:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[2:5]
# Out:
# ('three', 'four', 'five')

# %%
mytuple[:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:2]
# Out:
# ('one', 'two')

# %%
mytuple[-3:]
# Out:
# ('six', 'seven', 'eight')

# %%
mytuple[-2:]
# Out:
# ('seven', 'eight')

# %%
mytuple[-1]
# Out:
# 'eight'

# %%
mytuple[:]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %% [markdown]
# # remove and change items

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del mytuple{0} # tuples are immutable which means we can't DELETE tuple items
# Out:
#   Cell In[25], line 1
#     del mytuple{0} # tuples are immutable which means we can't DELETE tuple items
#                ^
# SyntaxError: invalid syntax

# %%
mytuple{0} = 1 # tuples are immutable which means we can't CHANGE tuple items
# Out:
#   Cell In[27], line 1
#     mytuple{0} = 1 # tuples are immutable which means we can't CHANGE tuple items
#            ^
# SyntaxError: invalid syntax

# %%
del mytuple # deleting entire tupleobject is possible

# %%
mytuple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 mytuple
#
# NameError: name 'mytuple' is not defined

# %% [markdown]
# # loop through a tuple

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
for i in mytuple:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# # tuple membership

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
'one' in mytuple # checks if 'one' exist in the list
# Out:
# True

# %%
'ten' in mytuple # checks if 'ten' exist in the list
# Out:
# False

# %%
if 'three' in mytuple:
    print('three is present in the tuple')
else:
    print('three is not present in the tuple')
# Out:
# three is present in the tuple

# %%
if 'eleven' in mytuple:
    print('eleven is present in the tuple')
else:
    print('eleven is not present in the tuple')
# Out:
# eleven is not present in the tuple

# %% [markdown]
# # index position

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple.index('one')
# Out:
# 0

# %%
mytuple.index('five')
# Out:
# 4

# %%
mytuple1 = ('one', 'two', 'three', 'four', 'one','one','two','three')

# %%
mytuple1
# Out:
# ('one', 'two', 'three', 'four', 'one', 'one', 'two', 'three')

# %%
mytuple1.index('one')
# Out:
# 0

# %% [markdown]
# # sorting

# %%
mytuple2 = (43,67,99,12,6,90,67)

# %%
sorted(mytuple2)
# Out:
# [6, 12, 43, 67, 67, 90, 99]

# %%
sorted(mytuple2, reverse=True)
# Out:
# [99, 90, 67, 67, 43, 12, 6]
